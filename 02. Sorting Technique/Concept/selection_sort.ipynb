# %% [markdown]
# # Selection Sort
# Selection Sort is one of the easiest sorting algorithms to learn because it follows a simple idea:
# > Find the smallest element and put it in its correct position. Repeat for the remaining unsorted part.
#
# ## Algorithm
# 1. Assume i contains the smallest element.
# 2. Search the remaining array.
# 3. If a smaller element is found, remember its index.
# 4. Swap the smallest element with arr[i].

# %%
# PYTHON CODE

arr = [29, 10, 14, 37, 13, 14, 0, 14]

n = len(arr)

for i in range(n):
    min_index = i

    for j in range(i + 1, n):
        if arr[j] < arr[min_index]:
            min_index = j

    arr[i], arr[min_index] = arr[min_index], arr[i]

print(arr)
# Out:
# [0, 10, 13, 14, 14, 14, 29, 37]

# %% [markdown]
# ## Time Complexity
# - Best Case : O(n^2)
# - Average Case : O(n^2)
# - Worst Case : O(n^2)
#
# ## Space Complexity
# - Alawys O(1)
# - It sorts the array in place, using only a few extra variables (i, j, and min_index).
